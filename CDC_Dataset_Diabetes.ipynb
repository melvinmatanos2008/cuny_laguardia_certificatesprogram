# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
from numpy.random import randn
np.random.seed(123)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import seaborn as sns
# %matplotlib inline

# %%
import seaborn as sns

# %%
df = pd.read_csv ('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv', index_col=0)
print(df)
# Out:
#               patient_nbr             race  ... diabetesMed readmitted
# encounter_id                                ...
# 2278392           8222157        Caucasian  ...          No         NO
# 149190           55629189        Caucasian  ...         Yes        >30
# 64410            86047875  AfricanAmerican  ...         Yes         NO
# 500364           82442376        Caucasian  ...         Yes         NO
# 16680            42519267        Caucasian  ...         Yes         NO
# ...                   ...              ...  ...         ...        ...
# 443847548       100162476  AfricanAmerican  ...         Yes        >30
# 443847782        74694222  AfricanAmerican  ...         Yes         NO
# 443854148        41088789        Caucasian  ...         Yes         NO
# 443857166        31693671        Caucasian  ...         Yes         NO
# 443867222       175429310        Caucasian  ...          No         NO
#
# [101766 rows x 49 columns]

# %%
pd.set_option('display.max_rows', df.shape[0]+1)

# %%
df.head(20)
# Out:
#               patient_nbr             race  ... diabetesMed readmitted
# encounter_id                                ...
# 2278392           8222157        Caucasian  ...          No         NO
# 149190           55629189        Caucasian  ...         Yes        >30
# 64410            86047875  AfricanAmerican  ...         Yes         NO
# 500364           82442376        Caucasian  ...         Yes         NO
# 16680            42519267        Caucasian  ...         Yes         NO
# 35754            82637451        Caucasian  ...         Yes        >30
# 55842            84259809        Caucasian  ...         Yes         NO
# 63768           114882984        Caucasian  ...         Yes        >30
# 12522            48330783        Caucasian  ...         Yes         NO
# 15738            63555939        Caucasian  ...         Yes         NO
# 28236            89869032  AfricanAmerican  ...         Yes        >30
# 36900            77391171  AfricanAmerican  ...         Yes        <30
# ...

# %%
df.tail()
# Out:
#               patient_nbr             race  ... diabetesMed readmitted
# encounter_id                                ...
# 443847548       100162476  AfricanAmerican  ...         Yes        >30
# 443847782        74694222  AfricanAmerican  ...         Yes         NO
# 443854148        41088789        Caucasian  ...         Yes         NO
# 443857166        31693671        Caucasian  ...         Yes         NO
# 443867222       175429310        Caucasian  ...          No         NO
#
# [5 rows x 49 columns]

# %%
df.describe()
# Out:
#         patient_nbr  admission_type_id  ...  number_inpatient  number_diagnoses
# count  1.017660e+05      101766.000000  ...     101766.000000     101766.000000
# mean   5.433040e+07           2.024006  ...          0.635566          7.422607
# std    3.869636e+07           1.445403  ...          1.262863          1.933600
# min    1.350000e+02           1.000000  ...          0.000000          1.000000
# 25%    2.341322e+07           1.000000  ...          0.000000          6.000000
# 50%    4.550514e+07           1.000000  ...          0.000000          8.000000
# 75%    8.754595e+07           3.000000  ...          1.000000          9.000000
# max    1.895026e+08           8.000000  ...         21.000000         16.000000
#
# [8 rows x 12 columns]

# %% [markdown]
# #Data Wrangling and cleaning of data.Finding the missing values.

# %%
df.isnull().sum()
# Out:
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# weight                      0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# ...

# %%
https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101766 entries, 2278392 to 443867222
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   patient_nbr               101766 non-null  int64
#  1   race                      101766 non-null  object
#  2   gender                    101766 non-null  object
#  3   age                       101766 non-null  object
#  4   weight                    101766 non-null  object
#  5   admission_type_id         101766 non-null  int64
#  6   discharge_disposition_id  101766 non-null  int64
#  7   admission_source_id       101766 non-null  int64
#  8   time_in_hospital          101766 non-null  int64
#  9   payer_code                101766 non-null  object
#  10  medical_specialty         101766 non-null  object
#  11  num_lab_procedures        101766 non-null  int64
#  12  num_procedures            101766 non-null  int64
# ...

# %% [markdown]
# # Showing data types summary of each columns in the dataframe

# %%
df.dtypes
# Out:
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# ...

# %% [markdown]
# # Showing example of a specific data types in dataframe

# %%
df.select_dtypes(include=['number'])
# Out:
#               patient_nbr  ...  number_diagnoses
# encounter_id               ...
# 2278392           8222157  ...                 1
# 149190           55629189  ...                 9
# 64410            86047875  ...                 6
# 500364           82442376  ...                 7
# 16680            42519267  ...                 5
# ...                   ...  ...               ...
# 443847548       100162476  ...                 9
# 443847782        74694222  ...                 9
# 443854148        41088789  ...                13
# 443857166        31693671  ...                 9
# 443867222       175429310  ...                 9
#
# [101766 rows x 12 columns]

# %%
df.index
# Out:
# Int64Index([  2278392,    149190,     64410,    500364,     16680,     35754,
#                 55842,     63768,     12522,     15738,
#             ...
#             443842070, 443842136, 443842340, 443842778, 443847176, 443847548,
#             443847782, 443854148, 443857166, 443867222],
#            dtype='int64', name='encounter_id', length=101766)

# %%
df.max()
# Out:
# patient_nbr                       189502619
# race                                  Other
# gender                      Unknown/Invalid
# age                                [90-100)
# weight                             [75-100)
# admission_type_id                         8
# discharge_disposition_id                 28
# admission_source_id                      25
# time_in_hospital                         14
# payer_code                               WC
# medical_specialty                   Urology
# num_lab_procedures                      132
# num_procedures                            6
# num_medications                          81
# number_outpatient                        42
# number_emergency                         76
# number_inpatient                         21
# diag_1                                  V71
# diag_2                                  V86
# diag_3                                  V86
# number_diagnoses                         16
# ...

# %%
df.min()
# Out:
# patient_nbr                    135
# race                             ?
# gender                      Female
# age                         [0-10)
# weight                        >200
# admission_type_id                1
# discharge_disposition_id         1
# admission_source_id              1
# time_in_hospital                 1
# payer_code                       ?
# medical_specialty                ?
# num_lab_procedures               1
# num_procedures                   0
# num_medications                  1
# number_outpatient                0
# number_emergency                 0
# number_inpatient                 0
# diag_1                          10
# diag_2                          11
# diag_3                          11
# number_diagnoses                 1
# max_glu_serum                 >200
# A1Cresult                       >7
# metformin                     Down
# repaglinide                   Down
# nateglinide                   Down
# chlorpropamide                Down
# ...

# %%
df.mean()
# Out:
# patient_nbr                 5.433040e+07
# admission_type_id           2.024006e+00
# discharge_disposition_id    3.715642e+00
# admission_source_id         5.754437e+00
# time_in_hospital            4.395987e+00
# num_lab_procedures          4.309564e+01
# num_procedures              1.339730e+00
# num_medications             1.602184e+01
# number_outpatient           3.693572e-01
# number_emergency            1.978362e-01
# number_inpatient            6.355659e-01
# number_diagnoses            7.422607e+00
# dtype: float64

# %% [markdown]
# # GroupBy() function

# %% [markdown]
# Which gender has the most admission?

# %%
df.groupby(["gender"]) ['admission_type_id'].count()
# Out:
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: admission_type_id, dtype: int64

# %%
df.groupby(["race"]) ['age'].count()
# Out:
# race
# ?                   2273
# AfricanAmerican    19210
# Asian                641
# Caucasian          76099
# Hispanic            2037
# Other               1506
# Name: age, dtype: int64

# %%
df[df['number_inpatient'] == df['number_inpatient'].max()]
# Out:
#               patient_nbr       race  gender  ... change diabetesMed  readmitted
# encounter_id                                  ...
# 103670874         4790016  Caucasian  Female  ...     No         Yes         <30
#
# [1 rows x 49 columns]

# %% [markdown]
# # What age has the highest number of insulin dependent?

# %%
df.groupby('age').insulin.describe()
# Out:
#           count unique     top   freq
# age
# [0-10)      161      4  Steady    100
# [10-20)     691      4  Steady    329
# [20-30)    1657      4  Steady    483
# [30-40)    3775      4      No   1473
# [40-50)    9685      4      No   4126
# [50-60)   17256      4      No   7780
# [60-70)   22483      4      No  10381
# [70-80)   26068      4      No  12937
# [80-90)   17197      4      No   8654
# [90-100)   2793      4      No   1451

# %% [markdown]
# # Visualization

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f681d9d0790>,
# ...
#       dtype=object)

# %%
df.plot()

# %%
df.plot(kind="hist", x="race" , y="number_outpatient")

# %%
corr = df.corr()
corr
# Out:
#                           patient_nbr  ...  number_diagnoses
# patient_nbr                  1.000000  ...          0.226847
# admission_type_id           -0.011128  ...         -0.117126
# discharge_disposition_id    -0.136814  ...          0.046891
# admission_source_id         -0.032568  ...          0.072114
# time_in_hospital            -0.024092  ...          0.220186
# num_lab_procedures           0.015946  ...          0.152773
# num_procedures              -0.015570  ...          0.073734
# num_medications              0.020665  ...          0.261526
# number_outpatient            0.103379  ...          0.094152
# number_emergency             0.062352  ...          0.055539
# number_inpatient             0.012480  ...          0.104710
# number_diagnoses             0.226847  ...          1.000000
#
# [12 rows x 12 columns]

# %%
sns.heatmap(corr)

# %%
fig, ax = plt.subplots(figsize=(7,5))
sns.heatmap(corr, square=True)

# %%
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(corr, mask=mask, vmax=1, square=True)

# %%
g = sns.PairGrid(df)
g.map(plt.scatter);
